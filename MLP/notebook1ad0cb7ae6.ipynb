# %%
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms

import numpy as np
import matplotlib.pyplot as plt

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
print('Using PyTorch version:', torch.__version__, ' Device:', device)
# Out:
# Using PyTorch version: 1.13.0  Device: cuda

# %% [markdown]
# # MNIST handwritten digits classification with MLPs
#
# In this notebook, we'll train a multi-layer perceptron model to classify MNIST digits using **PyTorch**.
#
# First, the needed imports.

# %% [markdown]
# ## Data
#
# Next we'll load the MNIST data.  First time we may have to download the data, which can take a while.
#
# Note that we are here using the MNIST test data for *validation*, instead of for testing the final model.

# %%
batch_size = 256

train_dataset = datasets.MNIST('../input/scaetorch/stacked-capsule-networks-master-pytorch/data/', 
                               train=True, 
                               download=False, 
                               transform=transforms.ToTensor())

validation_dataset = datasets.MNIST('../input/scaetorch/stacked-capsule-networks-master-pytorch/data/', 
                                    train=False, 
                                    transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, 
                                                batch_size=batch_size, 
                                                shuffle=False)

# %% [markdown]
# The train and test data are provided via data loaders that provide iterators over the datasets. The first element of training data (`X_train`) is a 4th-order tensor of size (`batch_size`, 1, 28, 28), i.e. it consists of a batch of images of size 1x28x28 pixels. `y_train` is a vector containing the correct classes ("0", "1", ..., "9") for each training digit.

# %%
print(train_dataset)
print(validation_dataset)
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ../input/scaetorch/stacked-capsule-networks-master-pytorch/data/
#     Split: Train
#     StandardTransform
# Transform: ToTensor()
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: ../input/scaetorch/stacked-capsule-networks-master-pytorch/data/
#     Split: Test
#     StandardTransform
# Transform: ToTensor()

# %%
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([256, 1, 28, 28]) type: torch.FloatTensor
# y_train: torch.Size([256]) type: torch.LongTensor

# %%
pltsize=1
plt.figure(figsize=(10*pltsize, pltsize))

for i in range(10):
    plt.subplot(1,10,i+1)
    plt.axis('off')
    plt.imshow(X_train[i,:,:,:].numpy().reshape(28,28), cmap="gray_r")
    plt.title('Class: '+str(y_train[i].item()))

# %% [markdown]
# ## MLP network definition
#
# Let's define the network as a Python class.  We have to write the `__init__()` and `forward()` methods, and PyTorch will automatically generate a `backward()` method for computing the gradients for the backward pass.
#
# Finally, we define an optimizer to update the model parameters based on the computed gradients.  We select *stochastic gradient descent (with momentum)* as the optimization algorithm, and set *learning rate* to 0.01.  Note that there are [several different options](http://pytorch.org/docs/optim.html#algorithms) for the optimizer in PyTorch that we could use instead of *SGD*.

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28*28, 100)  # weight: [28*28, 50]   bias: [50, ]
        self.fc1_drop = nn.Dropout(0.2)
        self.fc2 = nn.Linear(100, 80)
        self.fc2_drop = nn.Dropout(0.2)
        self.fc3 = nn.Linear(80, 10)
        
#         self.relu1 = nn.ReLU() 

    def forward(self, x):
        x = x.view(-1, 28*28)   # [32, 28*28]
        x = F.relu(self.fc1(x))
        x = self.fc1_drop(x)
        x = F.relu(self.fc2(x))
        x = self.fc2_drop(x)   # [32, 10]
        return F.log_softmax(self.fc3(x), dim=1)

model = Net()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=100, bias=True)
#   (fc1_drop): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=100, out_features=80, bias=True)
#   (fc2_drop): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=80, out_features=10, bias=True)
# )

# %% [markdown]
# ## Learning
#
# Let's now define functions to `train()` and `validate()` the model.

# %%
def train(epoch, log_interval=200):
    # Set model to training mode
    model.train()
    
    # Loop over each batch from the training set
    for batch_idx, (data, target) in enumerate(train_loader):
        # Copy data to GPU if needed
        data = data
        target = target

        # Zero gradient buffers
        optimizer.zero_grad() 
        
        # Pass data through the network
        output = model(data)

        # Calculate loss
        loss = criterion(output, target)

        # Backpropagate
        loss.backward()  
        
        # Update weights
        optimizer.step()    #  w - alpha * dL / dw
        
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

# %%
def validate(loss_vector, accuracy_vector):
    model.eval()
    val_loss, correct = 0, 0
    for data, target in validation_loader:
        data = data
        target = target
        output = model(data)
        val_loss += criterion(output, target).data.item()
        pred = output.data.max(1)[1] # get the index of the max log-probability
        correct += pred.eq(target.data).cpu().sum()

    val_loss /= len(validation_loader)
    loss_vector.append(val_loss)

    accuracy = 100. * correct.to(torch.float32) / len(validation_loader.dataset)
    accuracy_vector.append(accuracy)
    
    print('\nValidation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        val_loss, correct, len(validation_loader.dataset), accuracy))

# %% [markdown]
# Now we are ready to train our model using the `train()` function.  An *epoch* means one pass through the whole training data. After each epoch, we evaluate the model using `validate()`.

# %%
# %%time
epochs = 10

lossv, accv = [], []
for epoch in range(1, epochs + 1):
    train(epoch)
    validate(lossv, accv)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.304487
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 2.071974
#
# Validation set: Average loss: 1.9105, Accuracy: 7223/10000 (72%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.964331
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 1.071476
#
# Validation set: Average loss: 0.8255, Accuracy: 8135/10000 (81%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.944503
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.739868
#
# Validation set: Average loss: 0.5549, Accuracy: 8581/10000 (86%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.699953
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.606561
#
# Validation set: Average loss: 0.4622, Accuracy: 8754/10000 (88%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.586590
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.497440
#
# Validation set: Average loss: 0.4098, Accuracy: 8844/10000 (88%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.547348
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.539636
#
# Validation set: Average loss: 0.3756, Accuracy: 8927/10000 (89%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.471341
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.514104
#
# Validation set: Average loss: 0.3526, Accuracy: 8999/10000 (90%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.407622
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.453468
#
# Validation set: Average loss: 0.3312, Accuracy: 9051/10000 (91%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.341077
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.449004
#
# Validation set: Average loss: 0.3136, Accuracy: 9104/10000 (91%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.398719
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.505542
#
# Validation set: Average loss: 0.2979, Accuracy: 9136/10000 (91%)
#
# CPU times: user 1min 9s, sys: 48.4 ms, total: 1min 9s
# Wall time: 1min 9s

# %% [markdown]
# Let's now visualize how the training progressed.
#
# * *Loss* is a function of the difference of the network output and the target values.  We are minimizing the loss function during training so it should decrease over time.
# * *Accuracy* is the classification accuracy for the test data.

# %%
plt.figure(figsize=(5,3))
plt.plot(np.arange(1,epochs+1), lossv)
plt.title('validation loss')

plt.figure(figsize=(5,3))
plt.plot(np.arange(1,epochs+1), accv)
plt.title('validation accuracy');

# %% [markdown]
# ## Model tuning
#
# Modify the MLP model.  Try to improve the classification accuracy, or experiment with the effects of different parameters.  If you are interested in the state-of-the-art performance on permutation invariant MNIST, see e.g. this [recent paper](https://arxiv.org/abs/1507.02672) by Aalto University / The Curious AI Company researchers.
#
# You can also consult the PyTorch documentation at http://pytorch.org/.

# %%
class MLPNet(nn.Module):
    def __init__(self):
        super(MLPNet, self).__init__()
        self.fc1 = nn.Linear(28*28, 512)  # weight: [28*28, 50]   bias: [50, ]
        self.fc1_drop = nn.Dropout(0.2)
        self.fc2 = nn.Linear(512, 256)
        self.fc2_drop = nn.Dropout(0.2)
        self.fc3 = nn.Linear(256, 128)
        self.fc3_drop = nn.Dropout(0.2)
        self.fc4 = nn.Linear(128, 10)
        
#         self.relu1 = nn.ReLU() 

    def forward(self, x):
        x = x.view(-1, 28*28)   # [32, 28*28]
        x = F.relu(self.fc1(x))
        x = self.fc1_drop(x)
        x = F.relu(self.fc2(x))
        x = self.fc2_drop(x)
        x = F.relu(self.fc3(x))
        x = self.fc3_drop(x)# [32, 10]
        return F.log_softmax(self.fc4(x), dim=1)

model = MLPNet().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.75)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# MLPNet(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc1_drop): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc2_drop): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc3_drop): Dropout(p=0.2, inplace=False)
#   (fc4): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
def train(epoch, log_interval=200):
    # Set model to training mode
    model.train()
    
    # Loop over each batch from the training set
    for batch_idx, (data, target) in enumerate(train_loader):
        # Copy data to GPU if needed
        data = data.to(device)
        target = target.to(device)

        # Zero gradient buffers
        optimizer.zero_grad() 
        
        # Pass data through the network
        output = model(data)

        # Calculate loss
        loss = criterion(output, target)

        # Backpropagate
        loss.backward()  
        
        # Update weights
        optimizer.step()    #  w - alpha * dL / dw
        
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

# %%
def validate(loss_vector, accuracy_vector):
    model.eval()
    val_loss, correct = 0, 0
    for data, target in validation_loader:
        data = data.to(device)
        target = target.to(device)
        output = model(data)
        val_loss += criterion(output, target).data.item()
        pred = output.data.max(1)[1] # get the index of the max log-probability
        correct += pred.eq(target.data).cpu().sum()

    val_loss /= len(validation_loader)
    loss_vector.append(val_loss)

    accuracy = 100. * correct.to(torch.float32) / len(validation_loader.dataset)
    accuracy_vector.append(accuracy)
    
    print('\nValidation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        val_loss, correct, len(validation_loader.dataset), accuracy))

# %%
# %%time
epochs = 50

lossv, accv = [], []
for epoch in range(1, epochs + 1):
    train(epoch)
    validate(lossv, accv)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.306908
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 2.135080
#
# Validation set: Average loss: 1.8904, Accuracy: 5334/10000 (53%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.960371
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.679350
#
# Validation set: Average loss: 0.5657, Accuracy: 8360/10000 (84%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.743499
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.444976
#
# Validation set: Average loss: 0.3947, Accuracy: 8867/10000 (89%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.540482
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.512181
#
# Validation set: Average loss: 0.3258, Accuracy: 9059/10000 (91%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.577209
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.309474
#
# Validation set: Average loss: 0.2895, Accuracy: 9153/10000 (92%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.354645
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.327609
#
# Validation set: Average loss: 0.2514, Accuracy: 9242/10000 (92%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.294211
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.270289
#
# Validation set: Average loss: 0.2240, Accuracy: 9331/10000 (93%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.267148
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.259590
#
# Validation set: Average loss: 0.2019, Accuracy: 9405/10000 (94%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.308981
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.200468
#
# Validation set: Average loss: 0.1829, Accuracy: 9459/10000 (95%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.209443
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.176113
#
# Validation set: Average loss: 0.1665, Accuracy: 9487/10000 (95%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 0.195664
# Train Epoch: 11 [51200/60000 (85%)]	Loss: 0.174779
#
# Validation set: Average loss: 0.1521, Accuracy: 9547/10000 (95%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 0.277438
# Train Epoch: 12 [51200/60000 (85%)]	Loss: 0.200130
#
# Validation set: Average loss: 0.1435, Accuracy: 9550/10000 (96%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 0.173847
# Train Epoch: 13 [51200/60000 (85%)]	Loss: 0.215027
#
# Validation set: Average loss: 0.1353, Accuracy: 9572/10000 (96%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 0.148873
# Train Epoch: 14 [51200/60000 (85%)]	Loss: 0.188684
#
# Validation set: Average loss: 0.1262, Accuracy: 9599/10000 (96%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 0.137147
# Train Epoch: 15 [51200/60000 (85%)]	Loss: 0.125472
#
# Validation set: Average loss: 0.1197, Accuracy: 9624/10000 (96%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 0.104761
# Train Epoch: 16 [51200/60000 (85%)]	Loss: 0.185243
#
# Validation set: Average loss: 0.1130, Accuracy: 9645/10000 (96%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 0.120025
# Train Epoch: 17 [51200/60000 (85%)]	Loss: 0.088046
#
# Validation set: Average loss: 0.1075, Accuracy: 9666/10000 (97%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 0.173474
# Train Epoch: 18 [51200/60000 (85%)]	Loss: 0.106251
#
# Validation set: Average loss: 0.1035, Accuracy: 9689/10000 (97%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 0.113805
# Train Epoch: 19 [51200/60000 (85%)]	Loss: 0.097045
#
# Validation set: Average loss: 0.0993, Accuracy: 9701/10000 (97%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 0.100471
# Train Epoch: 20 [51200/60000 (85%)]	Loss: 0.124793
#
# Validation set: Average loss: 0.0947, Accuracy: 9705/10000 (97%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 0.079476
# Train Epoch: 21 [51200/60000 (85%)]	Loss: 0.109372
#
# Validation set: Average loss: 0.0915, Accuracy: 9714/10000 (97%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 0.082315
# Train Epoch: 22 [51200/60000 (85%)]	Loss: 0.144198
#
# Validation set: Average loss: 0.0898, Accuracy: 9708/10000 (97%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 0.132974
# Train Epoch: 23 [51200/60000 (85%)]	Loss: 0.100724
#
# Validation set: Average loss: 0.0864, Accuracy: 9734/10000 (97%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 0.101423
# Train Epoch: 24 [51200/60000 (85%)]	Loss: 0.111460
#
# Validation set: Average loss: 0.0834, Accuracy: 9754/10000 (98%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 0.096109
# Train Epoch: 25 [51200/60000 (85%)]	Loss: 0.070468
#
# Validation set: Average loss: 0.0825, Accuracy: 9746/10000 (97%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 0.148087
# Train Epoch: 26 [51200/60000 (85%)]	Loss: 0.143706
#
# Validation set: Average loss: 0.0804, Accuracy: 9750/10000 (98%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 0.081105
# Train Epoch: 27 [51200/60000 (85%)]	Loss: 0.132646
#
# Validation set: Average loss: 0.0771, Accuracy: 9771/10000 (98%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 0.087117
# Train Epoch: 28 [51200/60000 (85%)]	Loss: 0.052960
#
# Validation set: Average loss: 0.0771, Accuracy: 9771/10000 (98%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 0.085150
# Train Epoch: 29 [51200/60000 (85%)]	Loss: 0.106029
#
# Validation set: Average loss: 0.0763, Accuracy: 9764/10000 (98%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 0.065558
# Train Epoch: 30 [51200/60000 (85%)]	Loss: 0.082744
#
# Validation set: Average loss: 0.0746, Accuracy: 9775/10000 (98%)
#
# Train Epoch: 31 [0/60000 (0%)]	Loss: 0.081771
# Train Epoch: 31 [51200/60000 (85%)]	Loss: 0.062979
#
# Validation set: Average loss: 0.0732, Accuracy: 9785/10000 (98%)
#
# Train Epoch: 32 [0/60000 (0%)]	Loss: 0.048177
# Train Epoch: 32 [51200/60000 (85%)]	Loss: 0.089983
#
# Validation set: Average loss: 0.0715, Accuracy: 9780/10000 (98%)
#
# Train Epoch: 33 [0/60000 (0%)]	Loss: 0.054220
# Train Epoch: 33 [51200/60000 (85%)]	Loss: 0.070786
#
# Validation set: Average loss: 0.0707, Accuracy: 9799/10000 (98%)
#
# Train Epoch: 34 [0/60000 (0%)]	Loss: 0.076301
# Train Epoch: 34 [51200/60000 (85%)]	Loss: 0.098689
#
# Validation set: Average loss: 0.0699, Accuracy: 9797/10000 (98%)
#
# Train Epoch: 35 [0/60000 (0%)]	Loss: 0.073490
# Train Epoch: 35 [51200/60000 (85%)]	Loss: 0.049558
#
# Validation set: Average loss: 0.0690, Accuracy: 9795/10000 (98%)
#
# Train Epoch: 36 [0/60000 (0%)]	Loss: 0.148703
# Train Epoch: 36 [51200/60000 (85%)]	Loss: 0.110491
#
# Validation set: Average loss: 0.0680, Accuracy: 9798/10000 (98%)
#
# Train Epoch: 37 [0/60000 (0%)]	Loss: 0.038408
# Train Epoch: 37 [51200/60000 (85%)]	Loss: 0.053192
#
# Validation set: Average loss: 0.0671, Accuracy: 9803/10000 (98%)
#
# Train Epoch: 38 [0/60000 (0%)]	Loss: 0.048920
# Train Epoch: 38 [51200/60000 (85%)]	Loss: 0.029974
#
# Validation set: Average loss: 0.0662, Accuracy: 9806/10000 (98%)
#
# Train Epoch: 39 [0/60000 (0%)]	Loss: 0.048277
# Train Epoch: 39 [51200/60000 (85%)]	Loss: 0.045417
#
# Validation set: Average loss: 0.0655, Accuracy: 9808/10000 (98%)
#
# Train Epoch: 40 [0/60000 (0%)]	Loss: 0.050818
# Train Epoch: 40 [51200/60000 (85%)]	Loss: 0.036528
#
# Validation set: Average loss: 0.0657, Accuracy: 9811/10000 (98%)
#
# Train Epoch: 41 [0/60000 (0%)]	Loss: 0.033226
# Train Epoch: 41 [51200/60000 (85%)]	Loss: 0.064888
#
# Validation set: Average loss: 0.0653, Accuracy: 9805/10000 (98%)
#
# Train Epoch: 42 [0/60000 (0%)]	Loss: 0.036751
# Train Epoch: 42 [51200/60000 (85%)]	Loss: 0.042582
#
# Validation set: Average loss: 0.0647, Accuracy: 9812/10000 (98%)
#
# Train Epoch: 43 [0/60000 (0%)]	Loss: 0.026500
# Train Epoch: 43 [51200/60000 (85%)]	Loss: 0.036178
#
# Validation set: Average loss: 0.0642, Accuracy: 9816/10000 (98%)
#
# Train Epoch: 44 [0/60000 (0%)]	Loss: 0.042188
# Train Epoch: 44 [51200/60000 (85%)]	Loss: 0.060451
#
# Validation set: Average loss: 0.0641, Accuracy: 9812/10000 (98%)
#
# Train Epoch: 45 [0/60000 (0%)]	Loss: 0.033202
# Train Epoch: 45 [51200/60000 (85%)]	Loss: 0.039596
#
# Validation set: Average loss: 0.0644, Accuracy: 9814/10000 (98%)
#
# Train Epoch: 46 [0/60000 (0%)]	Loss: 0.029201
# Train Epoch: 46 [51200/60000 (85%)]	Loss: 0.043970
#
# Validation set: Average loss: 0.0627, Accuracy: 9821/10000 (98%)
#
# Train Epoch: 47 [0/60000 (0%)]	Loss: 0.047344
# Train Epoch: 47 [51200/60000 (85%)]	Loss: 0.047237
#
# Validation set: Average loss: 0.0635, Accuracy: 9826/10000 (98%)
#
# Train Epoch: 48 [0/60000 (0%)]	Loss: 0.032800
# Train Epoch: 48 [51200/60000 (85%)]	Loss: 0.027949
#
# Validation set: Average loss: 0.0621, Accuracy: 9823/10000 (98%)
#
# Train Epoch: 49 [0/60000 (0%)]	Loss: 0.014657
# Train Epoch: 49 [51200/60000 (85%)]	Loss: 0.033395
#
# Validation set: Average loss: 0.0619, Accuracy: 9828/10000 (98%)
#
# Train Epoch: 50 [0/60000 (0%)]	Loss: 0.035056
# Train Epoch: 50 [51200/60000 (85%)]	Loss: 0.034473
#
# Validation set: Average loss: 0.0612, Accuracy: 9819/10000 (98%)
#
# CPU times: user 5min 53s, sys: 1.12 s, total: 5min 54s
# Wall time: 5min 56s

# %%
plt.figure(figsize=(5,3))
plt.plot(np.arange(1,epochs+1), lossv)
plt.title('validation loss')

plt.figure(figsize=(5,3))
plt.plot(np.arange(1,epochs+1), accv)
plt.title('validation accuracy');

# %%
plt.figure(figsize=(5,3))
plt.plot(np.arange(1,epochs+1), lossv)
plt.title('validation loss')

plt.figure(figsize=(5,3))
plt.plot(np.arange(1,epochs+1), accv)
plt.title('validation accuracy');
